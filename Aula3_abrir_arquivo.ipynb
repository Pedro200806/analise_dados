# %%
import pandas as pd
import openpyxl

arquivo = "Tabela_3_Areas_gerais_de_formacao_na_graduacao.xlsx"

df = pd.read_excel(arquivo)

df
# Out:
#    Tabela 10063 - Pessoas com nível superior completo, por áreas gerais, específicas e detalhadas de formação do curso graduação concluído, segundo os grupos de idade, o sexo e a cor ou raça  \
# 0        Brasil, Grande Região e Unidade da Federação
# 1                                                 NaN
# 2                                              Brasil
# 3                                               Norte
# 4                                            Nordeste
# 5                                             Sudeste
# 6                                                 Sul
# 7                                        Centro-Oeste
# 8                                            Rondônia
# 9                                                Acre
# 10                                           Amazonas
# 11                                            Roraima
# 12                                               Pará
# 13                                              Amapá
# ...

# %%
import pandas as pd

dados = {
    "Região": [
        "Norte",
        "Nordeste",
        "Sudeste",
        "Sul",
        "Centro-Oeste"
    ],
    
    "Superior_Homens": [
        590558,
        1744994,
        5391638,
        1768855,
        982489
    ],
    
    "Superior_Mulheres": [
        934609,
        3003939,
        7437191,
        2570005,
        14300013
    ],
    
    "CTEM_Homens" : [
        590558,
        1744994,
        5391638,
        1768855,
        982489
    ],
    
    "CTEM_Mulheres": [
        76601,
        231395,
        739247,
        235543,
        115834
    ],
    
    "Educacao_Servicos_Saude_Homens": [
        141169,
        363905,
        768288,
        248574,
        156048
    ],
    
    "Educacao_Servicos_Saude_Mulheres": [
        458616,
        1458181,
        2884108,
        1007718,
        593101
        
    ]
}

df = pd.DataFrame(dados)

df
# Out:
#          Região  Superior_Homens  Superior_Mulheres  CTEM_Homens  \
# 0         Norte           590558             934609       590558
# 1      Nordeste          1744994            3003939      1744994
# 2       Sudeste          5391638            7437191      5391638
# 3           Sul          1768855            2570005      1768855
# 4  Centro-Oeste           982489           14300013       982489
#
#    CTEM_Mulheres  Educacao_Servicos_Saude_Homens  \
# 0          76601                          141169
# 1         231395                          363905
# 2         739247                          768288
# 3         235543                          248574
# 4         115834                          156048
#
#    Educacao_Servicos_Saude_Mulheres
# 0                            458616
# 1                           1458181
# 2                           2884108
# 3                           1007718
# 4                            593101

# %%
tabela_superior = df.loc[:,[
    "Região",
    "Superior_Homens",
    "Superior_Mulheres"
]]

tabela_superior
# Out:
#          Região  Superior_Homens  Superior_Mulheres
# 0         Norte           590558             934609
# 1      Nordeste          1744994            3003939
# 2       Sudeste          5391638            7437191
# 3           Sul          1768855            2570005
# 4  Centro-Oeste           982489           14300013

# %%
tabela_superior.describe()
# Out:
#        Superior_Homens  Superior_Mulheres
# count     5.000000e+00       5.000000e+00
# mean      2.095707e+06       5.649151e+06
# std       1.910348e+06       5.402307e+06
# min       5.905580e+05       9.346090e+05
# 25%       9.824890e+05       2.570005e+06
# 50%       1.744994e+06       3.003939e+06
# 75%       1.768855e+06       7.437191e+06
# max       5.391638e+06       1.430001e+07

# %%
tabela_ctem = df.loc[:,[
    "Região",
    "CTEM_Homens",
    "CTEM_Mulheres"
]]

tabela_ctem
# Out:
#          Região  CTEM_Homens  CTEM_Mulheres
# 0         Norte       590558          76601
# 1      Nordeste      1744994         231395
# 2       Sudeste      5391638         739247
# 3           Sul      1768855         235543
# 4  Centro-Oeste       982489         115834

# %%
tabela_ctem.describe()
# Out:
#         CTEM_Homens  CTEM_Mulheres
# count  5.000000e+00       5.000000
# mean   2.095707e+06  279724.000000
# std    1.910348e+06  266255.481521
# min    5.905580e+05   76601.000000
# 25%    9.824890e+05  115834.000000
# 50%    1.744994e+06  231395.000000
# 75%    1.768855e+06  235543.000000
# max    5.391638e+06  739247.000000

# %%
tabela_educacao = df.loc[:,[
    "Região",
    "Educacao_Servicos_Saude_Homens",
    "Educacao_Servicos_Saude_Mulheres"
]]

tabela_educacao
# Out:
#          Região  Educacao_Servicos_Saude_Homens  \
# 0         Norte                          141169
# 1      Nordeste                          363905
# 2       Sudeste                          768288
# 3           Sul                          248574
# 4  Centro-Oeste                          156048
#
#    Educacao_Servicos_Saude_Mulheres
# 0                            458616
# 1                           1458181
# 2                           2884108
# 3                           1007718
# 4                            593101

# %%
tabela_educacao.describe()
# Out:
#        Educacao_Servicos_Saude_Homens  Educacao_Servicos_Saude_Mulheres
# count                        5.000000                      5.000000e+00
# mean                    335596.800000                      1.280345e+06
# std                     257699.406993                      9.779506e+05
# min                     141169.000000                      4.586160e+05
# 25%                     156048.000000                      5.931010e+05
# 50%                     248574.000000                      1.007718e+06
# 75%                     363905.000000                      1.458181e+06
# max                     768288.000000                      2.884108e+06

# %%
print("ESTATÍSTICAS --CURSO SUPERIOR")
display(tabela_superior.describe())

print("ESTATÍSTICAS --CIÊNCIA, TECNOLOGIA, ENGENHARIAS E MATEMÁTICA")
display(tabela_ctem.describe())

print("ESTATÍSTICAS --EDUCAÇÃO, SERVIÇOS PESSOAIS, SAUDE E BEM-ESTAR")
display(tabela_educacao.describe())
# Out:
# ESTATÍSTICAS --CURSO SUPERIOR
#        Superior_Homens  Superior_Mulheres
# count     5.000000e+00       5.000000e+00
# mean      2.095707e+06       5.649151e+06
# std       1.910348e+06       5.402307e+06
# min       5.905580e+05       9.346090e+05
# 25%       9.824890e+05       2.570005e+06
# 50%       1.744994e+06       3.003939e+06
# 75%       1.768855e+06       7.437191e+06
# max       5.391638e+06       1.430001e+07
# ESTATÍSTICAS --CIÊNCIA, TECNOLOGIA, ENGENHARIAS E MATEMÁTICA
#         CTEM_Homens  CTEM_Mulheres
# count  5.000000e+00       5.000000
# mean   2.095707e+06  279724.000000
# std    1.910348e+06  266255.481521
# min    5.905580e+05   76601.000000
# 25%    9.824890e+05  115834.000000
# 50%    1.744994e+06  231395.000000
# 75%    1.768855e+06  235543.000000
# max    5.391638e+06  739247.000000
# ESTATÍSTICAS --EDUCAÇÃO, SERVIÇOS PESSOAIS, SAUDE E BEM-ESTAR
#        Educacao_Servicos_Saude_Homens  Educacao_Servicos_Saude_Mulheres
# ...
